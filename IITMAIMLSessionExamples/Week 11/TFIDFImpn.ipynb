# %%
#https://www.geeksforgeeks.org/machine-learning/understanding-tf-idf-term-frequency-inverse-document-frequency/
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
d0 = 'Welcome to World of Machine Learning'
d1 = 'Machine Learning World'
d2 = 'Python'
string = [d0, d1, d2]

# %%
tfidf = TfidfVectorizer()
result = tfidf.fit_transform(string)

# %%
print('\nidf values:')
for ele1, ele2 in zip(tfidf.get_feature_names_out(), tfidf.idf_):
    print(ele1, ':', ele2)
# Out:
# idf values:
# learning : 1.2876820724517808
# machine : 1.2876820724517808
# of : 1.6931471805599454
# python : 1.6931471805599454
# to : 1.6931471805599454
# welcome : 1.6931471805599454
# world : 1.2876820724517808

# %%
print('\nWord indexes:')
print(tfidf.vocabulary_)
print('\ntf-idf value:')
print(result)
print('\ntf-idf values in matrix form:')
print(result.toarray())
